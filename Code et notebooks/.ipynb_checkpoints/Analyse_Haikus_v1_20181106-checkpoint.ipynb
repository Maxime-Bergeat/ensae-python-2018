# %% [markdown]
# # Wordcloud sur haïkus

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
import os
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
### Ajout de la colonne avec l'auteur

# %%
os.chdir("C:/Users/maxim/Documents/Synchronisation OneDrive/OneDrive/Ensae - 2018 2020/2A/S1 - Python/Projet Python")

# %%
base_haikus = pd.read_csv("haikus_scraping_v1_20181106.csv")

# %%
base_haikus.columns
# Out:
# Index(['haiku'], dtype='object')

# %%
# Start with one review:
haikus = str(base_haikus["haiku"])

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(haikus)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
