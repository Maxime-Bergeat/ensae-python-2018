# %% [markdown]
# # Wordcloud sur haïkus

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
import os
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
os.chdir("C:/Users/maxim/Documents/ensae-python-2018/Data/")

# %%
base_haikus = pd.read_csv("haikus_fraction_20181108.csv","|")

# %%
base_haikus.head()
# Out:
#                                                 url   id_auteur   \
# 0  http://www.tempslibres.org/tl/tlphp/dbhk03.php...     quin-p
# 1  http://www.tempslibres.org/tl/tlphp/dbhk03.php...       py-d
# 2  http://www.tempslibres.org/tl/tlphp/dbhk03.php...     alex-m
# 3  http://www.tempslibres.org/tl/tlphp/dbhk03.php...     sang-r
# 4  http://www.tempslibres.org/tl/tlphp/dbhk03.php...     rais-c
#
#                auteur   sexe      pays   \
# 0     Philippe Quinta      H    France
# 1           Daniel Py      H    France
# 2       Marlène Alexa      F    Egypte
# 3   Rahmatou Sangotte      F    France
# 4      Carol Raisfeld      F       USA
#
#                                               haiku
# 0       Fut-elle pleine\\déjà, elle décroit\\la lune
# 1         Lune parfaitement ronde\\Buée sur la vitre
# 2   hiver\\dans les yeux de grand-mère\\une ombre...
# 3     gray skies -\\the smell of\\caramelized onions
# 4   la fille du pasteur\\sa robe du dimanche\\de ...

# %%
len(base_haikus)
# Out:
# 898

# %%
base_haikus[' haiku ']
# Out:
# 0           Fut-elle pleine\\déjà, elle décroit\\la lune
# 1             Lune parfaitement ronde\\Buée sur la vitre
# 2       hiver\\dans les yeux de grand-mère\\une ombre...
# 3         gray skies -\\the smell of\\caramelized onions
# 4       la fille du pasteur\\sa robe du dimanche\\de ...
# 5         Sans toi\\sous le ciel d'hiver\\nos pas perdus
# 6               petit noir -\\les cernes\\de la serveuse
# 7       Avant de partir,\\dans le miroir du salon\\te...
# 8       brusques giboulées -\\pleurs et puis rires de...
# 9       les mots sous les doigts\\l'aveugle et son li...
# 10      les jours s'allongent\\même la gloire du mati...
# 11      sur mon smartphone\\le mont fuji au soleil co...
# 12      l'orage s'éloigne -\\d'une fenêtre ouverte\\u...
# 13      nouvelle lune --\\la souris dans le grenier\\...
# 14             sundow\\still warmth\\in her rosary beads
# 15      encore errant\\dans le couloir vide --\\un pa...
# 16      sortant du métro\\face à face avec la lune -\...
# 17      j'oublie sa voix\\la lettre d'excuses de mon ...
# 18      journée mondiale du sida -\\je réinstalle\\mo...
# 19      soleil froid\\dans le parlement\\leurs hurlem...
# 20      ceinture brune : sa peau\\entre top et pantal...
# 21      fifteen elephants -\\after the storm\\the coc...
# 22      temps d'orage -\\sous les bottes le bruit\\de...
# 23      midi en avril\\les roseaux morts se frottent\...
# 24                   Mes doigts\\entre ses doigts\\Piano
# 25      sortie du tunnel -\\un champ de colza éclaire...
# 26      grosse lune du loup~\\quartier après quartier...
# 27      à chaque gorgée\\de la bouteille\\le clair de...
# 28      chaque soir\\au bout de la route\\l'usine Seveso
# 29      Harley Davidson \\rutilante de rosée - \\dima...
#                              ...
# 868     pont dans la nuit -\\j'essaie de me souvenir\...
# 869        Enterrement :\\Combler les 17 pieds\\du haïku
# 870     Goût de saké~\\dans la brume parfois\\le parf...
# 871     brise dans le lierre\\deux couples de papillo...
# 872     tonnerre du soir\\un sans-abri\\rassure son c...
# 873     journée torride\\à même la peau légère\\la ro...
# 874     flaque d'eau sur la grève\\son petit pied dis...
# 875     Réunion du soir -\\La jeune femme d'en face\\...
# 876     migration d'oies --\\personne ne leur demande...
# 877     ablation du sein\\entre la vie et la mort\\le...
# 878     Déshabillée\\elle parfume mes poignets\\la ma...
# 879        haïku\\written in the underground\\unreadable
# 880     place vide --\\il n'y a plus\\de lumières de ...
# 881        First morning\\   of the year, a lantern\\...
# 882     lavant mes vêtements\\quelqu'un me regarde\\c...
# 883     un galet rond -\\avant que vienne la nuit\\qu...
# 884     étable silencieuse...\\la force soudaine\\de ...
# 885      grandir sa poupée favorite maintenant vit seule
# 886     gris et pluvieux\\je vais avec ma mère\\à la ...
# 887                carrefour\\le coeur brun\\d'une pomme
# 888     Juno Beach-\\mon corps dans la mer,\\ma mère ...
# 889     autumn freshness\\nourishing a child\\of eigh...
# 890      sirènes de police --\\une autre nuit\\sans lune
# 891     à califourchon\\sur ma motocyclette\\le vent ...
# 892     rêve de neige -\\dans l'air froid du matin\\u...
# 893     Ascension\\un busard plane\\derrière le tracteur
# 894     nettoyage de printemps . . . \\je peins sur\\...
# 895     devant le poteau\\plus rien ni personne\\la g...
# 896     hall d'aéroport -\\ils poussent les chariots\...
# 897     husband gone-\\his watch ticks it's last tock...
# Name:  haiku , Length: 898, dtype: object

# %%
sum(base_haikus[' sexe ']==" F ")
# Out:
# 270

# %%
# Start with one review:
haikus = str(base_haikus[" haiku "])

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(haikus)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
### Remove stopwords
import nltk

from nltk.corpus import stopwords
stopwords = set(stopwords.words('french'))

# %%
wordcloud2 = WordCloud(   stopwords=stopwords,
                          background_color='white',
                          width=2500,
                          height=1800, 
                        max_words=100, 
                         ).generate(haikus)
plt.imshow(wordcloud2, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
haikus_F = str(base_haikus[base_haikus[' sexe '] == " F "][" haiku "])
haikus_H = str(base_haikus[base_haikus[' sexe '] == " H "][" haiku "])

# %%
# Wordcloud pour les haikus écrits par des hommes et des femmes

# Pour les femmes
masqueF = np.array(Image.open("images/symbole-femme.png"))
wordcloud_femmes = WordCloud(stopwords=stopwords, 
                             background_color="white", 
                             #mode="RGBA", 
                             max_words=100, 
                             mask=masqueF).generate(haikus_F)

# Pour les hommes
masqueH = np.array(Image.open("images/symbole-man2.png"))
wordcloud_hommes = WordCloud(stopwords=stopwords, 
                             background_color="white", 
                             mode="RGBA", 
                             max_words=100, 
                             mask=masqueH).generate(haikus_H)
# Plot
plt.figure(figsize=[7,7])
plt.imshow(wordcloud_femmes, interpolation="bilinear")
plt.imshow(wordcloud_hommes, interpolation="bilinear")
plt.axis("off")

# store to file
#plt.savefig("img/us_wine.png", format="png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-007b915e9a1b> in <module>()
#      19 plt.figure(figsize=[7,14])
#      20 plt.imshow(wordcloud_femmes, interpolation="bilinear")
# ---> 21 show()
#      22 plt.imshow(wordcloud_hommes, interpolation="bilinear")
#      23 show()
#
# NameError: name 'show' is not defined

# %%
# Pour les hommes
masqueH = np.array(Image.open("images/symbole-man2.png"))
wordcloud_hommes = WordCloud(stopwords=stopwords, 
                             background_color="white", 
                             mode="RGBA", 
                             max_words=100, 
                             mask=masqueH).generate(haikus_H)
# Plot
plt.figure(figsize=[7,7])
plt.imshow(wordcloud_hommes, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 188.5, 424.5, -0.5)

# %%
Image.open("images/symbole-man2.png")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=189x425 at 0x235DF4FB9B0>

# %%
stopwords
# Out:
# {'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'as',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'd',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'leur',
#  'lui',
#  'm',
#  'ma',
#  'mais',
#  'me',
#  'mes',
#  'moi',
#  'mon',
#  'même',
#  'n',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ont',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  's',
#  'sa',
#  'se',
#  'sera',
#  'serai',
#  'seraient',
#  'serais',
#  'serait',
#  'seras',
#  'serez',
#  'seriez',
#  'serions',
#  'serons',
#  'seront',
#  'ses',
#  'soient',
#  'sois',
#  'soit',
#  'sommes',
#  'son',
#  'sont',
#  'soyez',
#  'soyons',
#  'suis',
#  'sur',
#  't',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'y',
#  'à',
#  'étaient',
#  'étais',
#  'était',
#  'étant',
#  'étante',
#  'étantes',
#  'étants',
#  'étiez',
#  'étions',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'êtes'}
